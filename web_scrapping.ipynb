# %%
# Importing libraries
import pandas as pd

# %%
# Read CSV files from data folder and store in dataframes
hackathons = pd.read_csv('/Users/Isha/Desktop/TUe/Year 3/BEP/BEP_project/data/hackathons_modified.csv')
participants = pd.read_csv('/Users/Isha/Desktop/TUe/Year 3/BEP/BEP_project/data/participants_modified.csv')
participants_links = pd.read_csv('/Users/Isha/Desktop/TUe/Year 3/BEP/BEP_project/data/participants_links_modified.csv')
projects = pd.read_csv('/Users/Isha/Desktop/TUe/Year 3/BEP/BEP_project/data/projects_modified.csv')
# Out:
# /var/folders/_f/7jgfw7qx5jn8xl64g_9px9g00000gp/T/ipykernel_78257/2266132953.py:3: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   participants = pd.read_csv('/Users/Isha/Desktop/TUe/Year 3/BEP/BEP_project/data/participants_modified.csv')

# %%
pip install requests beautifulsoup4 pandas
# Out:
# Requirement already satisfied: requests in /Users/Isha/anaconda3/lib/python3.10/site-packages (2.28.1)
# Requirement already satisfied: beautifulsoup4 in /Users/Isha/anaconda3/lib/python3.10/site-packages (4.11.1)
# Requirement already satisfied: pandas in /Users/Isha/anaconda3/lib/python3.10/site-packages (1.5.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/Isha/anaconda3/lib/python3.10/site-packages (from requests) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/Isha/anaconda3/lib/python3.10/site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Isha/anaconda3/lib/python3.10/site-packages (from requests) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Isha/anaconda3/lib/python3.10/site-packages (from requests) (2022.12.7)
# Requirement already satisfied: soupsieve>1.2 in /Users/Isha/anaconda3/lib/python3.10/site-packages (from beautifulsoup4) (2.3.2.post1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/Isha/anaconda3/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/Isha/anaconda3/lib/python3.10/site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /Users/Isha/anaconda3/lib/python3.10/site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /Users/Isha/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

# %%
import requests

## Example
URL = "https://realpython.github.io/fake-jobs/"
page = requests.get(URL)

print(page.text)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <title>Fake Python</title>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bulma@0.9.2/css/bulma.min.css">
#   </head>
#   <body>
#   <section class="section">
#     <div class="container mb-5">
#       <h1 class="title is-1">
#         Fake Python
#       </h1>
#       <p class="subtitle is-3">
#         Fake Jobs for Your Web Scraping Journey
#       </p>
#     </div>
#     <div class="container">
#     <div id="ResultsContainer" class="columns is-multiline">
#     <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Senior Python Developer</h2>
#         <h3 class="subtitle is-6 company">Payne, Roberts and Davis</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Stewartbury, AA
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/senior-python-developer-0.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Energy engineer</h2>
#         <h3 class="subtitle is-6 company">Vasquez-Davidson</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Christopherville, AA
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/energy-engineer-1.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Legal executive</h2>
#         <h3 class="subtitle is-6 company">Jackson, Chambers and Levy</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Port Ericaburgh, AA
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/legal-executive-2.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Fitness centre manager</h2>
#         <h3 class="subtitle is-6 company">Savage-Bradley</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         East Seanview, AP
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/fitness-centre-manager-3.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Product manager</h2>
#         <h3 class="subtitle is-6 company">Ramirez Inc</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         North Jamieview, AP
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/product-manager-4.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Medical technical officer</h2>
#         <h3 class="subtitle is-6 company">Rogers-Yates</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Davidville, AP
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/medical-technical-officer-5.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Physiological scientist</h2>
#         <h3 class="subtitle is-6 company">Kramer-Klein</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         South Christopher, AE
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/physiological-scientist-6.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Textile designer</h2>
#         <h3 class="subtitle is-6 company">Meyers-Johnson</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Port Jonathan, AE
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/textile-designer-7.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Television floor manager</h2>
#         <h3 class="subtitle is-6 company">Hughes-Williams</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Osbornetown, AE
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/television-floor-manager-8.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Waste management officer</h2>
#         <h3 class="subtitle is-6 company">Jones, Williams and Villa</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Scotttown, AP
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/waste-management-officer-9.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Software Engineer (Python)</h2>
#         <h3 class="subtitle is-6 company">Garcia PLC</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Ericberg, AE
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/software-engineer-python-10.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Interpreter</h2>
#         <h3 class="subtitle is-6 company">Gregory and Sons</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Ramireztown, AE
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/interpreter-11.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Architect</h2>
#         <h3 class="subtitle is-6 company">Clark, Garcia and Sosa</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Figueroaview, AA
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/architect-12.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Meteorologist</h2>
#         <h3 class="subtitle is-6 company">Bush PLC</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Kelseystad, AA
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/meteorologist-13.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Audiological scientist</h2>
#         <h3 class="subtitle is-6 company">Salazar-Meyers</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Williamsburgh, AE
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/audiological-scientist-14.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">English as a second language teacher</h2>
#         <h3 class="subtitle is-6 company">Parker, Murphy and Brooks</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Mitchellburgh, AE
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/english-as-a-second-language-teacher-15.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Surgeon</h2>
#         <h3 class="subtitle is-6 company">Cruz-Brown</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         West Jessicabury, AA
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/surgeon-16.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Equities trader</h2>
#         <h3 class="subtitle is-6 company">Macdonald-Ferguson</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Maloneshire, AE
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/equities-trader-17.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Newspaper journalist</h2>
#         <h3 class="subtitle is-6 company">Williams, Peterson and Rojas</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Johnsonton, AA
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/newspaper-journalist-18.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Materials engineer</h2>
#         <h3 class="subtitle is-6 company">Smith and Sons</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         South Davidtown, AP
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/materials-engineer-19.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Python Programmer (Entry-Level)</h2>
#         <h3 class="subtitle is-6 company">Moss, Duncan and Allen</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Port Sara, AE
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/python-programmer-entry-level-20.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Product/process development scientist</h2>
#         <h3 class="subtitle is-6 company">Gomez-Carroll</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Marktown, AA
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/product-process-development-scientist-21.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Scientist, research (maths)</h2>
#         <h3 class="subtitle is-6 company">Manning, Welch and Herring</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Laurenland, AE
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/scientist-research-maths-22.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Ecologist</h2>
#         <h3 class="subtitle is-6 company">Lee, Gutierrez and Brown</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Lauraton, AP
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/ecologist-23.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Materials engineer</h2>
#         <h3 class="subtitle is-6 company">Davis, Serrano and Cook</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         South Tammyberg, AP
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/materials-engineer-24.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Historic buildings inspector/conservation officer</h2>
#         <h3 class="subtitle is-6 company">Smith LLC</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         North Brandonville, AP
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/historic-buildings-inspector-conservation-officer-25.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Data scientist</h2>
#         <h3 class="subtitle is-6 company">Thomas Group</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Port Robertfurt, AA
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/data-scientist-26.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Psychiatrist</h2>
#         <h3 class="subtitle is-6 company">Silva-King</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Burnettbury, AE
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/psychiatrist-27.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Structural engineer</h2>
#         <h3 class="subtitle is-6 company">Pierce-Long</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Herbertside, AA
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/structural-engineer-28.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Immigration officer</h2>
#         <h3 class="subtitle is-6 company">Walker-Simpson</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Christopherport, AP
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/immigration-officer-29.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Python Programmer (Entry-Level)</h2>
#         <h3 class="subtitle is-6 company">Cooper and Sons</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         West Victor, AE
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/python-programmer-entry-level-30.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Neurosurgeon</h2>
#         <h3 class="subtitle is-6 company">Donovan, Gonzalez and Figueroa</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Port Aaron, AP
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/neurosurgeon-31.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Broadcast engineer</h2>
#         <h3 class="subtitle is-6 company">Morgan, Butler and Bennett</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Loribury, AA
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/broadcast-engineer-32.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Make</h2>
#         <h3 class="subtitle is-6 company">Snyder-Lee</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Angelastad, AP
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/make-33.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Nurse, adult</h2>
#         <h3 class="subtitle is-6 company">Harris PLC</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Larrytown, AE
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/nurse-adult-34.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Air broker</h2>
#         <h3 class="subtitle is-6 company">Washington PLC</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         West Colin, AP
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/air-broker-35.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Editor, film/video</h2>
#         <h3 class="subtitle is-6 company">Brown, Price and Campbell</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         West Stephanie, AP
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/editor-film-video-36.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Production assistant, radio</h2>
#         <h3 class="subtitle is-6 company">Mcgee PLC</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Laurentown, AP
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/production-assistant-radio-37.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Engineer, communications</h2>
#         <h3 class="subtitle is-6 company">Dixon Inc</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Wrightberg, AP
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/engineer-communications-38.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Sales executive</h2>
#         <h3 class="subtitle is-6 company">Thompson, Sheppard and Ward</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Alberttown, AE
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/sales-executive-39.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Software Developer (Python)</h2>
#         <h3 class="subtitle is-6 company">Adams-Brewer</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Brockburgh, AE
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/software-developer-python-40.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Futures trader</h2>
#         <h3 class="subtitle is-6 company">Schneider-Brady</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         North Jason, AE
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/futures-trader-41.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Tour manager</h2>
#         <h3 class="subtitle is-6 company">Gonzales-Frank</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Arnoldhaven, AE
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/tour-manager-42.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Cytogeneticist</h2>
#         <h3 class="subtitle is-6 company">Smith-Wong</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Lake Destiny, AP
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/cytogeneticist-43.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Designer, multimedia</h2>
#         <h3 class="subtitle is-6 company">Pierce-Herrera</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         South Timothyburgh, AP
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/designer-multimedia-44.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Trade union research officer</h2>
#         <h3 class="subtitle is-6 company">Aguilar, Rivera and Quinn</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         New Jimmyton, AE
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
# ...
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/printmaker-84.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Health and safety adviser</h2>
#         <h3 class="subtitle is-6 company">Eaton PLC</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         North Stephen, AE
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/health-and-safety-adviser-85.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Manufacturing systems engineer</h2>
#         <h3 class="subtitle is-6 company">Stanley-Frederick</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Stevensland, AP
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/manufacturing-systems-engineer-86.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Programmer, applications</h2>
#         <h3 class="subtitle is-6 company">Bradley LLC</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Reyesstad, AE
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/programmer-applications-87.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Medical physicist</h2>
#         <h3 class="subtitle is-6 company">Parker, Goodwin and Zavala</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Bellberg, AP
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/medical-physicist-88.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Media planner</h2>
#         <h3 class="subtitle is-6 company">Kim-Miles</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         North Johnland, AE
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/media-planner-89.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Software Developer (Python)</h2>
#         <h3 class="subtitle is-6 company">Moreno-Rodriguez</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Martinezburgh, AE
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/software-developer-python-90.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Surveyor, land/geomatics</h2>
#         <h3 class="subtitle is-6 company">Brown-Ortiz</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Joshuatown, AE
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/surveyor-land-geomatics-91.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Legal executive</h2>
#         <h3 class="subtitle is-6 company">Hartman PLC</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         West Ericstad, AA
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/legal-executive-92.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Librarian, academic</h2>
#         <h3 class="subtitle is-6 company">Brooks Inc</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Tuckertown, AE
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/librarian-academic-93.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Barrister</h2>
#         <h3 class="subtitle is-6 company">Washington-Castillo</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Perezton, AE
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/barrister-94.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Museum/gallery exhibitions officer</h2>
#         <h3 class="subtitle is-6 company">Nguyen, Yoder and Petty</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Lake Abigail, AE
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/museum-gallery-exhibitions-officer-95.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Radiographer, diagnostic</h2>
#         <h3 class="subtitle is-6 company">Holder LLC</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Jacobshire, AP
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/radiographer-diagnostic-96.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Database administrator</h2>
#         <h3 class="subtitle is-6 company">Yates-Ferguson</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Port Susan, AE
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/database-administrator-97.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Furniture designer</h2>
#         <h3 class="subtitle is-6 company">Ortega-Lawrence</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         North Tiffany, AA
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/furniture-designer-98.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
# <div class="column is-half">
# <div class="card">
#   <div class="card-content">
#     <div class="media">
#       <div class="media-left">
#         <figure class="image is-48x48">
#           <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">
#         </figure>
#       </div>
#       <div class="media-content">
#         <h2 class="title is-5">Ship broker</h2>
#         <h3 class="subtitle is-6 company">Fuentes, Walls and Castro</h3>
#       </div>
#     </div>
#
#     <div class="content">
#       <p class="location">
#         Michelleville, AP
#       </p>
#       <p class="is-small has-text-grey">
#         <time datetime="2021-04-08">2021-04-08</time>
#       </p>
#     </div>
#     <footer class="card-footer">
#         <a href="https://www.realpython.com" target="_blank" class="card-footer-item">Learn</a>
#         <a href="https://realpython.github.io/fake-jobs/jobs/ship-broker-99.html" target="_blank" class="card-footer-item">Apply</a>
#     </footer>
#   </div>
# </div>
# </div>
#
#     </div>
#     </div>
#   </section>
#   </body>
# </html>

# %%
hackathon_urls = hackathons['start_a_submission_url']

# %% [markdown]
# ### Learning from Datacamp - Webscraping with Python

# %%
from scrapy import Selector
html = '''
<html>
    <body>
        <div class="hello datacamp">
            <p>Hello World!</p>
        </div>
        <p>Enjoy Datacamp!</p>
    </body>
</html>
'''

sel = Selector(text=html) ## sel has selected the entire document
sel.xpath('//p')
## outputs 2 selectorLists of Selector objects:
# Out:
# [<Selector xpath='//p' data='<p>Hello World!</p>'>,
#  <Selector xpath='//p' data='<p>Enjoy Datacamp!</p>'>]

# %%
## but if you want to get just the strings then use extract()
sel.xpath('//p').extract()
# Out:
# ['<p>Hello World!</p>', '<p>Enjoy Datacamp!</p>']

# %%
sel.xpath('//p').extract_first() ## to get the first piece of data from the selector list
# Out:
# '<p>Hello World!</p>'

# %%
## Or could alternatively use the following:
ps = sel.xpath('//p')
second_p = ps[1] ## to get the second selector in the list p, but since python lists start at index 0, we call it using [1]
second_p.extract() # outputs the string
# Out:
# '<p>Enjoy Datacamp!</p>'

# %% [markdown]
# ## Trying on the dataset hackathons using one row

# %%
import requests
hackathon_urls = hackathons['start_a_submission_url']
url_trial = hackathon_urls[0] ## choosing the second entry in the list
html_trial = requests.get(url_trial).content # loading the html content of the link
sel_trial = Selector(text=html_trial) # creating a Selector object called sel_trial

# %%
print(url_trial)
sel_trial.xpath('//*[@id="introduction"]/div/div[1]/h3').extract() # trial to see what the div tags for the html - SUBTITLES
# Out:
# https://wirvsvirushackathon.devpost.com/challenges/start_a_submission
# ['<h3 class="mb-6">Wie können wir als Gesellschaft die Herausforderungen, die im Zuge der Corona Krise entstehen, mit neuen Lösungen gemeinsam meistern?</h3>']

# %%
sel_trial.xpath('//*[@id="challenge-sponsors-side"]/h3').extract() # SPONSORS
# Out:
# ['<h3 class="text-center">Hackathon sponsors</h3>']

# %%
sel_trial.xpath('//*[@id="challenge-information"]/section[3]/div/div/a[1]/span').extract() # TAGS
# Out:
# ['<span href="#" class="label theme-label mr-1 mb-2">\n                  Social Good\n                </span>']

# %%
sel_trial.xpath('//*[@id="judges"]/div[2]/div/div/div[2]/p').extract() # JUDGES
# Out:
# ['<p>\n                <strong>Jury</strong><br>\n                <i></i>\n              </p>']

# %%
sel_trial.xpath('//*[@id="judging-criteria"]/ul').extract() # JUDGING CRITERIA
# Out:
# ['<ul class="no-bullet">\n      <li>\n        <strong>Gesellschaftlicher Mehrwert</strong><br>\n        Mehrwert, den die Lösung der Gesellschaft bringt. Hier zählt auch, ob die Lösung Open Source ist, sodass andere darauf aufbauen können. Wie vielen Menschen hilft die Lösung und wie sehr? Wie sehr trägt die Lösung zur Open-Source-Community bei?\n      </li>\n      <li>\n        <strong>Innovationsgrad</strong><br>\n        Innovationsgrad und Kreativität der Lösungsidee sowie des beabsichtigten Ansatzes oder der Technologie, mit der die Lösung implementiert wird. Gibt es bestehende oder ähnliche Lösungen? Wie unterscheiden sie sich von dieser?\n      </li>\n      <li>\n        <strong>Skalierbarkeit</strong><br>\n        Skalierbarkeit der Lösung, wenn sie implementiert und realisiert wird. Was ist der erwartete Bedarf? Wie viele Menschen sind betroffen und profitieren von der Lösung? Wie viele können es benutzen oder sind bereit, dafür zu zahlen.\n      </li>\n      <li>\n        <strong>Fortschritt</strong><br>\n        Fortschritt, der im Hackathon erzielt wurde. Dabei gilt: gut dokumentierte Zwischenstände, auf die aufgebaut werden kann, sind besser als möglichst viel Code. Was habt ihr in den letzten 48 Stunden geschafft? Wie gut lässt sich darauf aufbauen? \n      </li>\n      <li>\n        <strong>Verständlichkeit</strong><br>\n        Verständlichkeit des Projekts und welche Herausforderung mit der Lösungsidee wie gelöst werden soll, einschließlich der Gruppe an Menschen die betroffen ist und profitieren würde. Wie gut ist die Lösung kommuniziert und dokumentiert?\n      </li>\n  </ul>']

# %%
import pandas as pd
import requests
from scrapy import Selector

# Assuming 'hackathons' is your DataFrame
hackathon_urls = hackathons['start_a_submission_url'][:2] # just applying to first 2 rows to check functionality first

# Function to scrape data from a hackathon URL
def scrape_hackathon_data(url):
    html_content = requests.get(url).content
    sel = Selector(text=html_content)

    # Extracting data
    subtitles = sel.xpath('//*[@id="introduction"]/div/div[1]/h3').extract()
    sponsors = sel.xpath('//*[@id="challenge-sponsors-side"]/h3').extract()
    tags = sel.xpath('//*[@id="challenge-information"]/section[3]/div/div/a[1]/span').extract()
    judges = sel.xpath('//*[@id="judges"]/div[2]/div/div/div[2]/p').extract()
    judging_criteria = sel.xpath('//*[@id="judging-criteria"]/ul').extract()

    # Return the scraped data
    return {
        'subtitles': subtitles,
        'sponsors': sponsors,
        'tags': tags,
        'judges': judges,
        'judging_criteria': judging_criteria
    }

# Apply the scraping function to all rows in the DataFrame
scraped_data = hackathon_urls.apply(scrape_hackathon_data)

# Merge the scraped data back into the original DataFrame
hackathons_with_scraped_data = pd.concat([hackathons, scraped_data], axis=1)

# Display the resulting DataFrame
hackathons_with_scraped_data
# Out:
#       Unnamed: 0                                           URL  \
# 0              0      https://wirvsvirushackathon.devpost.com/
# 1              4            https://theglobalhack.devpost.com/
# 2              8                https://supernova.devpost.com/
# 3             12            https://hajjhackathon.devpost.com/
# 4             16      https://chainlinkspring2022.devpost.com/
# ...          ...                                           ...
# 7048        7075           https://checkinproject.devpost.com/
# 7049        7076                  https://fgtfrgf.devpost.com/
# 7050        7077                https://old-hacks.devpost.com/
# 7051        7078  https://thailand-champion-13627.devpost.com/
# 7052        7079        https://manager-hackathon.devpost.com/
#
#                                                Criteria     schedule  \
# 0     Gesellschaftlicher Mehrwert, Innovationsgrad, ...  no schedule
# 1     Potential impact of the project, Technical exe...  no schedule
# 2     X Factor and Potential, Technical Competence, ...  no schedule
# 3     Design           |             التصميم, Simpli...  no schedule
# 4     User Experience / User Interface, Originality ...  no schedule
# ...                                                 ...          ...
# 7048                                              biden  no schedule
# 7049                   Criteria 1, Criteria 1, criteria  no schedule
# 7050                                                TBA  no schedule
# 7051                                              biden  no schedule
# 7052                                     Firts criteria  no schedule
#
#      hack_type                                               info  \
# 0       Public  Mar 29, 2020, Online, Public, Social Good     ...
# 1       Public             Apr 12, 2020, Online, Public, COVID-19
# 2       Public  Jul 11, 2022, Online, Public, DFINITY Foundati...
# 3       Public  Aug 3, 2018, Jeddah International Exhibition &...
# 4       Public  Jun 8, 2022, Online, Public, Chainlink Labs, B...
# ...        ...                                                ...
# 7048    Public  Aug 30, 2021, Thái Lan, Public, ACM Monterrey,...
# 7049    Public  Jul 15, 2021, Online, Public, Dong Trinh LTD, ...
# 7050    Public  May 7, 2021, Quận 2, Vietnam, Public, Hackers ...
# 7051    Public  Sep 15, 2021, Thái Lan, Public, Screen Compose...
# 7052    Public  Aug 9, 2021, Việt Nam, Public, Girls Who Code ...
#
#      start_date_format end_date_format  \
# 0           2020-03-20      2020-03-22
# 1           2020-04-03      2020-04-09
# 2           2022-05-10      2022-06-22
# 3           2018-08-01      2018-08-03
# 4           2022-04-22      2022-05-28
# ...                ...             ...
# 7048        2021-08-30      2021-08-30
# 7049        2021-07-15      2021-07-15
# 7050        2021-05-07      2021-05-07
# 7051        2021-09-15      2021-09-15
# 7052        2021-08-09      2021-08-09
#
#                                                  Prizes     prize_money  ...  \
# 0     Euer Preis ist Anerkennung und Ehre!, Habt Spa...  no money prize  ...
# 1                                        Overall Winner  no money prize  ...
# 2     SocialFi - 1ST PLACE, SocialFi - 2ND PLACE, So...        $765,000  ...
# 3     1st place: 1 million Saudi Riyal (15% equity i...    SAR2,000,000  ...
# 4     Chainlink Grand Prize - $40,000, Chainlink NFT...      $1,019,000  ...
# ...                                                 ...             ...  ...
# 7048                                         cash value          $1,000  ...
# 7049               1st place, 2nd place, 3rd place, 4nd          $1,100  ...
# 7050                                                TBA  no money prize  ...
# 7051                                      Thailand cash            $100  ...
# 7052                                                  1              $1  ...
#
#        year                                  themes prize registered_N  \
# 0      2020                   Social Good, COVID-19    $0        12505
# 1      2020                                COVID-19    €0         6059
# 2      2022     Social Good, Blockchain, Open Ended    $0         3633
# 3      2018                           Not Specified  SAR0         2935
# 4      2022                Blockchain, Web, Fintech    $0         1481
# ...     ...                                     ...   ...          ...
# 7048   2021                            Voice skills    $0            1
# 7049   2021  AR/VR, Machine Learning/AI, Open Ended    $0            1
# 7050   2021                              Open Ended    $0            1
# 7051   2021                            Voice skills    $0            0
# 7052   2021                            Voice skills    $0            0
#
#      featured                         organization_name winners_announced  \
# 0       False                             Not Specified             False
# 1       False                             Not Specified             False
# 2       False                        DFINITY Foundation             False
# 3       False                             Not Specified             False
# 4       False                            Chainlink Labs             False
# ...       ...                                       ...               ...
# 7048    False                             ACM Monterrey              True
# 7049    False                            Dong Trinh LTD              True
# 7050    False                            Hackers Galore              True
# 7051    False  Screen Composers Guild of Canada & SOCAN              True
# 7052    False                        Girls Who Code UVA              True
#
#                                  submission_gallery_url  \
# 0     https://wirvsvirushackathon.devpost.com/projec...
# 1     https://theglobalhack.devpost.com/project-gallery
# 2         https://supernova.devpost.com/project-gallery
# 3     https://hajjhackathon.devpost.com/project-gallery
# 4     https://chainlinkspring2022.devpost.com/projec...
# ...                                                 ...
# 7048  https://checkinproject.devpost.com/project-gal...
# 7049        https://fgtfrgf.devpost.com/project-gallery
# 7050      https://old-hacks.devpost.com/project-gallery
# 7051  https://thailand-champion-13627.devpost.com/pr...
# 7052  https://manager-hackathon.devpost.com/project-...
#
#                                  start_a_submission_url  \
# 0     https://wirvsvirushackathon.devpost.com/challe...
# 1     https://theglobalhack.devpost.com/challenges/s...
# 2     https://supernova.devpost.com/challenges/start...
# 3     https://hajjhackathon.devpost.com/challenges/s...
# 4     https://chainlinkspring2022.devpost.com/challe...
# ...                                                 ...
# 7048  https://checkinproject.devpost.com/challenges/...
# 7049  https://fgtfrgf.devpost.com/challenges/start_a...
# 7050  https://old-hacks.devpost.com/challenges/start...
# 7051  https://thailand-champion-13627.devpost.com/ch...
# 7052  https://manager-hackathon.devpost.com/challeng...
#
#                                  start_a_submission_url
# 0     {'subtitles': ['<h3 class="mb-6">Wie können wi...
# 1     {'subtitles': ['<h3 class="mb-6">Fighting a Gl...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7048                                                NaN
# 7049                                                NaN
# 7050                                                NaN
# 7051                                                NaN
# 7052                                                NaN
#
# [7053 rows x 25 columns]

# %%
import requests
from scrapy import Selector

# Extract the first few URLs from the hackathon_urls series
hackathon_urls = hackathons['start_a_submission_url'][:2]  # Change the number to adjust the number of rows to process

# Loop through each URL and extract data
for url in hackathon_urls:
    try:
        html_content = requests.get(url).content
        sel = Selector(text=html_content)

        # Extracting data using XPath expressions
        subtitles = sel.xpath('//*[@id="introduction"]/div/div[1]/h3').extract()
        sponsors = sel.xpath('//*[@id="challenge-sponsors-side"]/h3').extract()
        tags = sel.xpath('//*[@id="challenge-information"]/section[3]/div/div/a[1]/span').extract()
        judges = sel.xpath('//*[@id="judges"]/div[2]/div/div/div[2]/p').extract()
        judging_criteria = sel.xpath('//*[@id="judging-criteria"]/ul').extract()

        # Print or store the extracted data
        print("URL:", url)
        print("Subtitles:", subtitles)
        print("Sponsors:", sponsors)
        print("Tags:", tags)
        print("Judges:", judges)
        print("Judging Criteria:", judging_criteria)
        print("\n")
    except Exception as e:
        print("Error fetching data from URL:", url)
        print("Error:", e)
# Out:
# URL: https://wirvsvirushackathon.devpost.com/challenges/start_a_submission
# Subtitles: ['<h3 class="mb-6">Wie können wir als Gesellschaft die Herausforderungen, die im Zuge der Corona Krise entstehen, mit neuen Lösungen gemeinsam meistern?</h3>']
# Sponsors: ['<h3 class="text-center">Hackathon sponsors</h3>']
# Tags: ['<span href="#" class="label theme-label mr-1 mb-2">\n                  Social Good\n                </span>']
# Judges: ['<p>\n                <strong>Jury</strong><br>\n                <i></i>\n              </p>']
# Judging Criteria: ['<ul class="no-bullet">\n      <li>\n        <strong>Gesellschaftlicher Mehrwert</strong><br>\n        Mehrwert, den die Lösung der Gesellschaft bringt. Hier zählt auch, ob die Lösung Open Source ist, sodass andere darauf aufbauen können. Wie vielen Menschen hilft die Lösung und wie sehr? Wie sehr trägt die Lösung zur Open-Source-Community bei?\n      </li>\n      <li>\n        <strong>Innovationsgrad</strong><br>\n        Innovationsgrad und Kreativität der Lösungsidee sowie des beabsichtigten Ansatzes oder der Technologie, mit der die Lösung implementiert wird. Gibt es bestehende oder ähnliche Lösungen? Wie unterscheiden sie sich von dieser?\n      </li>\n      <li>\n        <strong>Skalierbarkeit</strong><br>\n        Skalierbarkeit der Lösung, wenn sie implementiert und realisiert wird. Was ist der erwartete Bedarf? Wie viele Menschen sind betroffen und profitieren von der Lösung? Wie viele können es benutzen oder sind bereit, dafür zu zahlen.\n      </li>\n      <li>\n        <strong>Fortschritt</strong><br>\n        Fortschritt, der im Hackathon erzielt wurde. Dabei gilt: gut dokumentierte Zwischenstände, auf die aufgebaut werden kann, sind besser als möglichst viel Code. Was habt ihr in den letzten 48 Stunden geschafft? Wie gut lässt sich darauf aufbauen? \n      </li>\n      <li>\n        <strong>Verständlichkeit</strong><br>\n        Verständlichkeit des Projekts und welche Herausforderung mit der Lösungsidee wie gelöst werden soll, einschließlich der Gruppe an Menschen die betroffen ist und profitieren würde. Wie gut ist die Lösung kommuniziert und dokumentiert?\n      </li>\n  </ul>']
#
#
# URL: https://theglobalhack.devpost.com/challenges/start_a_submission
# Subtitles: ['<h3 class="mb-6">Fighting a Global Crisis - 3 billion people in lockdown. Let\'s hack the future so we never go through this again.</h3>']
# Sponsors: []
# Tags: ['<span href="#" class="label theme-label mr-1 mb-2">\n                  COVID-19\n                </span>']
# Judges: ['<p>\n                <strong>TBA</strong><br>\n                <i></i>\n              </p>']
# Judging Criteria: ['<ul class="no-bullet">\n      <li>\n        <strong>Potential impact of the project</strong><br>\n        \n      </li>\n      <li>\n        <strong>Technical execution during the Hackathon 9-11th of April</strong><br>\n        \n      </li>\n      <li>\n        <strong>The Video submission (project and demo) in the end of the Hackathon</strong><br>\n        \n      </li>\n  </ul>']

# %%
import requests
from lxml import html
import pandas as pd
from scrapy import Selector
import numpy as np

# Function to extract data from a URL
def extract_data(url):
    if pd.isna(url):  # Check if the URL is NaN
        return None

    try:
        html_content = requests.get(url).content
        sel = Selector(text=html_content)

        # Extracting data using XPath expressions
        subtitles = sel.xpath('//*[@id="introduction"]/div/div[1]/h3/text()').extract_first()
       # sponsors = sel.xpath('//*[contains(@id, "challenge-sponsors-side")]/descendant::*/text()').extract()
        sponsors_data = sel.xpath('//*[@id="challenge-sponsors-side"]/h3/following-sibling::*').extract()
        tags = sel.xpath('//*[@id="challenge-information"]/section[3]/div/div/a[1]/span/text()').extract()
        judges = sel.xpath('//*[@id="judges"]//div//p/strong').extract()
        judging_criteria = sel.xpath('//*[@id="judging-criteria"]/ul/li/strong/text()').extract()
        #eligibility = sel.xpath('//*[@id="challenge-eligibility"]/h3/following-sibling::*').extract()
        eligibility = sel.xpath('//section//article[contains(., "eligibility") or position()=2]').extract()
        requirements = sel.xpath('//section//div/div[1]/article[position()=2 or position()=3]/div[2]').extract()


        return {
            'Subtitles': subtitles,
            'Sponsors': sponsors_data,
            'Tags': tags,
            'Judges': judges,
            'Judging Criteria': judging_criteria,
            'Eligibility': eligibility,
            'Requirements':requirements
        }
    except Exception as e:
        print("Error fetching data from URL:", url)
        print("Error:", e)
        return None

# Apply the function to each URL in the DataFrame
hackathons['extracted_data'] = hackathons['URL'].apply(extract_data)

# Extract each data component into separate columns
for column in ['Subtitles', 'Sponsors', 'Tags', 'Judges', 'Judging Criteria', 'Eligibility', 'Requirements']:
    hackathons[column] = hackathons['extracted_data'].apply(lambda x: x.get(column) if isinstance(x, dict) else None)

# Drop the temporary 'extracted_data' column
hackathons.drop(columns=['extracted_data'], inplace=True)

# Display the modified DataFrame
hackathons[['URL', 'Subtitles', 'Sponsors', 'Tags', 'Judges', 'Judging Criteria', 'Eligibility', 'Requirements']]
# Out:
# Error fetching data from URL: https://hackumbcfall2020.devpost.com/
# Error: HTTPSConnectionPool(host='hackumbcfall2020.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23ab90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://healthhack20.devpost.com/
# Error: HTTPSConnectionPool(host='healthhack20.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b820>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://global-design-challenge.devpost.com/
# Error: HTTPSConnectionPool(host='global-design-challenge.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23ab90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hackprinceton-f19.devpost.com/
# Error: HTTPSConnectionPool(host='hackprinceton-f19.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23add0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://watson.devpost.com/
# Error: HTTPSConnectionPool(host='watson.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bbe0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hacknroll2016.devpost.com/
# Error: HTTPSConnectionPool(host='hacknroll2016.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23af80>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://myscript.devpost.com/
# Error: HTTPSConnectionPool(host='myscript.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b160>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://gsatraveldata.devpost.com/
# Error: HTTPSConnectionPool(host='gsatraveldata.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23ae30>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://ignition-hacks-2021.devpost.com/
# Error: HTTPSConnectionPool(host='ignition-hacks-2021.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23ac80>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hack-ccessible.devpost.com/
# Error: HTTPSConnectionPool(host='hack-ccessible.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b7f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hacked-2021.devpost.com/
# Error: HTTPSConnectionPool(host='hacked-2021.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bb50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hackital2017.devpost.com/
# Error: HTTPSConnectionPool(host='hackital2017.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bbe0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://super-utilizers.devpost.com/
# Error: HTTPSConnectionPool(host='super-utilizers.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b820>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hackiethon.devpost.com/
# Error: HTTPSConnectionPool(host='hackiethon.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bd00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://effect-network-hackathon.devpost.com/
# Error: HTTPSConnectionPool(host='effect-network-hackathon.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23ab90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://covidhacks.devpost.com/
# Error: HTTPSConnectionPool(host='covidhacks.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23acb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://start-hack-2019.devpost.com/
# Error: HTTPSConnectionPool(host='start-hack-2019.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b7f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hackatown-2019.devpost.com/
# Error: HTTPSConnectionPool(host='hackatown-2019.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bb50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://datasci-17.devpost.com/
# Error: HTTPSConnectionPool(host='datasci-17.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bbe0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://unihack2022.devpost.com/
# Error: HTTPSConnectionPool(host='unihack2022.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b820>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://pearlhacks2021.devpost.com/
# Error: HTTPSConnectionPool(host='pearlhacks2021.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bd00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://sasehack2020.devpost.com/
# Error: HTTPSConnectionPool(host='sasehack2020.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23ab90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://inmobihackday2014.devpost.com/
# Error: HTTPSConnectionPool(host='inmobihackday2014.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23acb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://citrushack2021.devpost.com/
# Error: HTTPSConnectionPool(host='citrushack2021.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b7f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://cmshub.devpost.com/
# Error: HTTPSConnectionPool(host='cmshub.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bb50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://datadaygrind.devpost.com/
# Error: HTTPSConnectionPool(host='datadaygrind.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bbe0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://ohlonehacks.devpost.com/
# Error: HTTPSConnectionPool(host='ohlonehacks.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b820>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hacknc2017.devpost.com/
# Error: HTTPSConnectionPool(host='hacknc2017.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bd00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hackrice-7.devpost.com/
# Error: HTTPSConnectionPool(host='hackrice-7.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23ab90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://brh2017.devpost.com/
# Error: HTTPSConnectionPool(host='brh2017.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23acb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://stellarnft.devpost.com/
# Error: HTTPSConnectionPool(host='stellarnft.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b7f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://snakesandhackers.devpost.com/
# Error: HTTPSConnectionPool(host='snakesandhackers.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bb50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://cisco-meraki-hackathon-2020.devpost.com/
# Error: HTTPSConnectionPool(host='cisco-meraki-hackathon-2020.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bbe0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://makeharvard2020.devpost.com/
# Error: HTTPSConnectionPool(host='makeharvard2020.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b820>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hackny-f2018.devpost.com/
# Error: HTTPSConnectionPool(host='hackny-f2018.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bd00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hackalong.devpost.com/
# Error: HTTPSConnectionPool(host='hackalong.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23ab90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hackrpi2016.devpost.com/
# Error: HTTPSConnectionPool(host='hackrpi2016.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23acb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hackfsu16.devpost.com/
# Error: HTTPSConnectionPool(host='hackfsu16.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b7f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://rootstech2015.devpost.com/
# Error: HTTPSConnectionPool(host='rootstech2015.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bb50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://qhacks-2022.devpost.com/
# Error: HTTPSConnectionPool(host='qhacks-2022.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bbe0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://profitechack.devpost.com/
# Error: HTTPSConnectionPool(host='profitechack.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b820>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hack-it-better.devpost.com/
# Error: HTTPSConnectionPool(host='hack-it-better.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bd00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://unbox-your-ideas.devpost.com/
# Error: HTTPSConnectionPool(host='unbox-your-ideas.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23ab90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://uottahack3.devpost.com/
# Error: HTTPSConnectionPool(host='uottahack3.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23acb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://bots-for-good.devpost.com/
# Error: HTTPSConnectionPool(host='bots-for-good.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b7f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://splunkapptitude2.devpost.com/
# Error: HTTPSConnectionPool(host='splunkapptitude2.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bb50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://yoapp.devpost.com/
# Error: HTTPSConnectionPool(host='yoapp.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bbe0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://howdyhack2021.devpost.com/
# Error: HTTPSConnectionPool(host='howdyhack2021.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b820>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://socialthon.devpost.com/
# Error: HTTPSConnectionPool(host='socialthon.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bd00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://attshapehackathon.devpost.com/
# Error: HTTPSConnectionPool(host='attshapehackathon.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23ab90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://lauzhack2018.devpost.com/
# Error: HTTPSConnectionPool(host='lauzhack2018.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23acb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hackgsu-fall-2017.devpost.com/
# Error: HTTPSConnectionPool(host='hackgsu-fall-2017.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b7f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://appathon21.devpost.com/
# Error: HTTPSConnectionPool(host='appathon21.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bb50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://blinkathon.devpost.com/
# Error: HTTPSConnectionPool(host='blinkathon.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bbe0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://jumpstart.devpost.com/
# Error: HTTPSConnectionPool(host='jumpstart.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b820>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://raccoons-virtual-hackathon.devpost.com/
# Error: HTTPSConnectionPool(host='raccoons-virtual-hackathon.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bd00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://gtsportschallenge2.devpost.com/
# Error: HTTPSConnectionPool(host='gtsportschallenge2.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23ab90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://oceanprotocol.devpost.com/
# Error: HTTPSConnectionPool(host='oceanprotocol.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23acb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://ubclhd19.devpost.com/
# Error: HTTPSConnectionPool(host='ubclhd19.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b7f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://athenahacks2018.devpost.com/
# Error: HTTPSConnectionPool(host='athenahacks2018.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bb50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://dubhacks18f.devpost.com/
# Error: HTTPSConnectionPool(host='dubhacks18f.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bbe0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hackisu-viii.devpost.com/
# Error: HTTPSConnectionPool(host='hackisu-viii.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b820>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hackebolawithdata.devpost.com/
# Error: HTTPSConnectionPool(host='hackebolawithdata.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bd00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://jamhacks6.devpost.com/
# Error: HTTPSConnectionPool(host='jamhacks6.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23ab90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hacktx-2021.devpost.com/
# Error: HTTPSConnectionPool(host='hacktx-2021.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23acb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://harmony.devpost.com/
# Error: HTTPSConnectionPool(host='harmony.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b7f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://onerecord.devpost.com/
# Error: HTTPSConnectionPool(host='onerecord.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bb50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hackcovid-2.devpost.com/
# Error: HTTPSConnectionPool(host='hackcovid-2.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bbe0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://dragonhacks2020.devpost.com/
# Error: HTTPSConnectionPool(host='dragonhacks2020.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b820>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://vthacks7.devpost.com/
# Error: HTTPSConnectionPool(host='vthacks7.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bd00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://junctionxkaust2019.devpost.com/
# Error: HTTPSConnectionPool(host='junctionxkaust2019.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23ab90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://sxswhackathon2019.devpost.com/
# Error: HTTPSConnectionPool(host='sxswhackathon2019.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23acb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://sfhacks.devpost.com/
# Error: HTTPSConnectionPool(host='sfhacks.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b7f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hackny-s2017.devpost.com/
# Error: HTTPSConnectionPool(host='hackny-s2017.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bb50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hackfair2021.devpost.com/
# Error: HTTPSConnectionPool(host='hackfair2021.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bbe0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hacklarious.devpost.com/
# Error: HTTPSConnectionPool(host='hacklarious.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b820>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://athenahacks2020.devpost.com/
# Error: HTTPSConnectionPool(host='athenahacks2020.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bd00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hackbu.devpost.com/
# Error: HTTPSConnectionPool(host='hackbu.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23ab90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hackatown2018.devpost.com/
# Error: HTTPSConnectionPool(host='hackatown2018.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23acb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://ethlisbon.devpost.com/
# Error: HTTPSConnectionPool(host='ethlisbon.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b7f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://unihack21.devpost.com/
# Error: HTTPSConnectionPool(host='unihack21.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bb50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://techtogether-new-york-2020.devpost.com/
# Error: HTTPSConnectionPool(host='techtogether-new-york-2020.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bbe0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://winter.devpost.com/
# Error: HTTPSConnectionPool(host='winter.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b820>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hackumbcfall2019.devpost.com/
# Error: HTTPSConnectionPool(host='hackumbcfall2019.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bd00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://teenhacks-li-spring-2019.devpost.com/
# Error: HTTPSConnectionPool(host='teenhacks-li-spring-2019.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23ab90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://wyominghackathon.devpost.com/
# Error: HTTPSConnectionPool(host='wyominghackathon.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23acb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://ubhacking2017.devpost.com/
# Error: HTTPSConnectionPool(host='ubhacking2017.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b7f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hackatum.devpost.com/
# Error: HTTPSConnectionPool(host='hackatum.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bb50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://medhacks2016.devpost.com/
# Error: HTTPSConnectionPool(host='medhacks2016.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bbe0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hacktheblock.devpost.com/
# Error: HTTPSConnectionPool(host='hacktheblock.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b820>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://vizathon-2021.devpost.com/
# Error: HTTPSConnectionPool(host='vizathon-2021.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bd00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hacklbs.devpost.com/
# Error: HTTPSConnectionPool(host='hacklbs.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23ab90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://bonhacketit.devpost.com/
# Error: HTTPSConnectionPool(host='bonhacketit.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23acb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://xdhax.devpost.com/
# Error: HTTPSConnectionPool(host='xdhax.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b7f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hackmty2016.devpost.com/
# Error: HTTPSConnectionPool(host='hackmty2016.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bb50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://ugahacks-6.devpost.com/
# Error: HTTPSConnectionPool(host='ugahacks-6.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bbe0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://qhacks-2021.devpost.com/
# Error: HTTPSConnectionPool(host='qhacks-2021.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b820>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://gs1hackathon2020.devpost.com/
# Error: HTTPSConnectionPool(host='gs1hackathon2020.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bd00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://naijahacks2018.devpost.com/
# Error: HTTPSConnectionPool(host='naijahacks2018.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23ab90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://citrushack2018.devpost.com/
# Error: HTTPSConnectionPool(host='citrushack2018.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23acb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://tamuhack-2016.devpost.com/
# Error: HTTPSConnectionPool(host='tamuhack-2016.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b7f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://multitouch.devpost.com/
# Error: HTTPSConnectionPool(host='multitouch.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bb50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://inkathon.devpost.com/
# Error: HTTPSConnectionPool(host='inkathon.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bbe0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hackruf15.devpost.com/
# Error: HTTPSConnectionPool(host='hackruf15.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b820>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hackanode.devpost.com/
# Error: HTTPSConnectionPool(host='hackanode.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bd00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://impressjs.devpost.com/
# Error: HTTPSConnectionPool(host='impressjs.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23ab90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://appsforvehicles.devpost.com/
# Error: HTTPSConnectionPool(host='appsforvehicles.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23acb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://infusionsoft2012.devpost.com/
# Error: HTTPSConnectionPool(host='infusionsoft2012.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b7f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://warde-high-school.devpost.com/
# Error: HTTPSConnectionPool(host='warde-high-school.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bb50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://mit-reality-hack-2022.devpost.com/
# Error: HTTPSConnectionPool(host='mit-reality-hack-2022.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bbe0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://athena-hack-2021.devpost.com/
# Error: HTTPSConnectionPool(host='athena-hack-2021.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b820>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://newhacks2020.devpost.com/
# Error: HTTPSConnectionPool(host='newhacks2020.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bd00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://onerecord2021.devpost.com/
# Error: HTTPSConnectionPool(host='onerecord2021.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23ab90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://newfriendsnewhacks.devpost.com/
# Error: HTTPSConnectionPool(host='newfriendsnewhacks.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23acb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://bigredhacks.devpost.com/
# Error: HTTPSConnectionPool(host='bigredhacks.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b7f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hackpsu-spring-2021.devpost.com/
# Error: HTTPSConnectionPool(host='hackpsu-spring-2021.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bb50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hackbu-2021.devpost.com/
# Error: HTTPSConnectionPool(host='hackbu-2021.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bbe0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://health-hacks.devpost.com/
# Error: HTTPSConnectionPool(host='health-hacks.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b820>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://brhfa19.devpost.com/
# Error: HTTPSConnectionPool(host='brhfa19.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bd00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hackny-s2015.devpost.com/
# Error: HTTPSConnectionPool(host='hackny-s2015.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23ab90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://nucleotide-hackathon.devpost.com/
# Error: HTTPSConnectionPool(host='nucleotide-hackathon.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23acb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://rte.devpost.com/
# Error: HTTPSConnectionPool(host='rte.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b7f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://globalgraphhack.devpost.com/
# Error: HTTPSConnectionPool(host='globalgraphhack.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bb50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://shehacks3.devpost.com/
# Error: HTTPSConnectionPool(host='shehacks3.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bbe0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://ramhacks2018.devpost.com/
# Error: HTTPSConnectionPool(host='ramhacks2018.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b820>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hackcmu-2016.devpost.com/
# Error: HTTPSConnectionPool(host='hackcmu-2016.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bd00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hackatmacs.devpost.com/
# Error: HTTPSConnectionPool(host='hackatmacs.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23ab90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://tizenapps.devpost.com/
# Error: HTTPSConnectionPool(host='tizenapps.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23acb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://ru-hacks-2022-digital-15171.devpost.com/
# Error: HTTPSConnectionPool(host='ru-hacks-2022-digital-15171.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b7f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://whodoneithacks.devpost.com/
# Error: HTTPSConnectionPool(host='whodoneithacks.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bb50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hecochain-hackathon.devpost.com/
# Error: HTTPSConnectionPool(host='hecochain-hackathon.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bbe0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://ethboston.devpost.com/
# Error: HTTPSConnectionPool(host='ethboston.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b820>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://isbhacks2017.devpost.com/
# Error: HTTPSConnectionPool(host='isbhacks2017.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bd00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://fall-hackmty-2016-4121.devpost.com/
# Error: HTTPSConnectionPool(host='fall-hackmty-2016-4121.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23ab90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://conuhacks.devpost.com/
# ...
# Error fetching data from URL: https://amogus.devpost.com/
# Error: HTTPSConnectionPool(host='amogus.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b790>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://ihs-cs-intertrack-hackathon.devpost.com/
# Error: HTTPSConnectionPool(host='ihs-cs-intertrack-hackathon.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23af80>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://femhacks-2-0.devpost.com/
# Error: HTTPSConnectionPool(host='femhacks-2-0.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bb50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hack-sprint-winter-2021.devpost.com/
# Error: HTTPSConnectionPool(host='hack-sprint-winter-2021.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b160>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hbap-pitch-competition-test.devpost.com/
# Error: HTTPSConnectionPool(host='hbap-pitch-competition-test.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b820>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hack-for-covid.devpost.com/
# Error: HTTPSConnectionPool(host='hack-for-covid.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23ab90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://bothell-club-hackathon.devpost.com/
# Error: HTTPSConnectionPool(host='bothell-club-hackathon.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bbe0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://gdsc-wit-challenge.devpost.com/
# Error: HTTPSConnectionPool(host='gdsc-wit-challenge.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b790>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://apps-for-teens.devpost.com/
# Error: HTTPSConnectionPool(host='apps-for-teens.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23af80>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://health-hack-covid.devpost.com/
# Error: HTTPSConnectionPool(host='health-hack-covid.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bb50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://provihack.devpost.com/
# Error: HTTPSConnectionPool(host='provihack.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b160>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hackaton-dev.devpost.com/
# Error: HTTPSConnectionPool(host='hackaton-dev.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b820>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://hackme.devpost.com/
# Error: HTTPSConnectionPool(host='hackme.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23ab90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://sf-global-progcomp.devpost.com/
# Error: HTTPSConnectionPool(host='sf-global-progcomp.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bbe0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://test-14191.devpost.com/
# Error: HTTPSConnectionPool(host='test-14191.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b790>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://sairi-hackathon-2021-autumn.devpost.com/
# Error: HTTPSConnectionPool(host='sairi-hackathon-2021-autumn.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23af80>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://market-challenge-us.devpost.com/
# Error: HTTPSConnectionPool(host='market-challenge-us.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bb50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://testinghack4cause.devpost.com/
# Error: HTTPSConnectionPool(host='testinghack4cause.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b160>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://sample-hackathon-draft.devpost.com/
# Error: HTTPSConnectionPool(host='sample-hackathon-draft.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b820>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://slash-test-2022.devpost.com/
# Error: HTTPSConnectionPool(host='slash-test-2022.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23ab90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://pfic-challenge.devpost.com/
# Error: HTTPSConnectionPool(host='pfic-challenge.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bbe0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://filipino-startup-incubato.devpost.com/
# Error: HTTPSConnectionPool(host='filipino-startup-incubato.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b790>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://bay-area-hacks-2021-12377.devpost.com/
# Error: HTTPSConnectionPool(host='bay-area-hacks-2021-12377.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23af80>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://checkinproject.devpost.com/
# Error: HTTPSConnectionPool(host='checkinproject.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bb50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://fgtfrgf.devpost.com/
# Error: HTTPSConnectionPool(host='fgtfrgf.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b160>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://old-hacks.devpost.com/
# Error: HTTPSConnectionPool(host='old-hacks.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23b820>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://thailand-champion-13627.devpost.com/
# Error: HTTPSConnectionPool(host='thailand-champion-13627.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23ab90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching data from URL: https://manager-hackathon.devpost.com/
# Error: HTTPSConnectionPool(host='manager-hackathon.devpost.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x13f23bbe0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#                                                URL  \
# 0         https://wirvsvirushackathon.devpost.com/
# 1               https://theglobalhack.devpost.com/
# 2                   https://supernova.devpost.com/
# 3               https://hajjhackathon.devpost.com/
# 4         https://chainlinkspring2022.devpost.com/
# ...                                            ...
# 7048           https://checkinproject.devpost.com/
# 7049                  https://fgtfrgf.devpost.com/
# 7050                https://old-hacks.devpost.com/
# 7051  https://thailand-champion-13627.devpost.com/
# 7052        https://manager-hackathon.devpost.com/
#
#                                               Subtitles  \
# 0     Wie können wir als Gesellschaft die Herausford...
# 1     Fighting a Global Crisis - 3 billion people in...
# 2                      Internet Computer Web3 Hackathon
# 3     #Hajj_Hackathon                               ...
# 4     Build the next generation of Web3 apps with $5...
# ...                                                 ...
# 7048                                               None
# 7049                                               None
# 7050                                               None
# 7051                                               None
# 7052                                               None
#
#                                                Sponsors  \
# 0     [<a target="_blank" title="Go to Impact Hub Be...
# 1                                                    []
# 2     [<img id="sponsor_logo_polychain capital" clas...
# 3                                                    []
# 4     [<h5>Platinum Sponsors</h5>, <img id="sponsor_...
# ...                                                 ...
# 7048                                               None
# 7049                                               None
# 7050                                               None
# 7051                                               None
# 7052                                               None
#
#                                                    Tags  \
# 0     [\n                  Social Good\n            ...
# 1      [\n                  COVID-19\n                ]
# 2     [\n                DFINITY Foundation\n       ...
# 3                                                    []
# 4     [\n                Chainlink Labs\n           ...
# ...                                                 ...
# 7048                                               None
# 7049                                               None
# 7050                                               None
# 7051                                               None
# 7052                                               None
#
#                                                  Judges  \
# 0                               [<strong>Jury</strong>]
# 1                                [<strong>TBA</strong>]
# 2     [<strong>Olaf Carlson-Wee</strong>, <strong>Ma...
# 3                                [<strong>TBD</strong>]
# 4     [<strong>Austin Griffith</strong>, <strong>All...
# ...                                                 ...
# 7048                                               None
# 7049                                               None
# 7050                                               None
# 7051                                               None
# 7052                                               None
#
#                                        Judging Criteria  \
# 0     [Gesellschaftlicher Mehrwert, Innovationsgrad,...
# 1     [Potential impact of the project, Technical ex...
# 2     [X Factor and Potential, Technical Competence,...
# 3     [Design           |             التصميم , Simp...
# 4     [User Experience / User Interface, Originality...
# ...                                                 ...
# 7048                                               None
# 7049                                               None
# 7050                                               None
# 7051                                               None
# 7052                                               None
#
#                                             Eligibility  \
# 0     [<article id="challenge-eligibility">\n      <...
# 1     [<article id="challenge-eligibility">\n      <...
# 2     [<article id="challenge-requirements">\n      ...
# 3     [<article id="challenge-requirements">\n      ...
# 4     [<article id="challenge-requirements">\n      ...
# ...                                                 ...
# 7048                                               None
# 7049                                               None
# 7050                                               None
# 7051                                               None
# 7052                                               None
#
#                                            Requirements
# 0     [<div>\n        <p><span>Diese Hackathon Seite...
# 1     [<div>\n        <p><strong>Participants:</stro...
# 2     [<div>\n        <h4>HACKATHON TRACKS</h4>\n<p>...
# 3     [<div>\n        <p> </p>\n<ul>\n<li><strong>De...
# 4     [<div>\n        <p>Each project must use Chain...
# ...                                                 ...
# 7048                                               None
# 7049                                               None
# 7050                                               None
# 7051                                               None
# 7052                                               None
#
# [7053 rows x 8 columns]

# %%
hackathons.to_csv('hackathon_scraped_subset_100.csv', index=False)

# %% [markdown]
# Seeing some elements closer to check if the scraping worked as planned:

# %%
#print(hackathons['Eligibility'][0]) # pulled reguirements for some eligibility for some and SPONSORS FOR SOME
print(hackathons['Requirements'][0])
#print(hackathons['Sponsors'][7])
#print(hackathons['URL'][7])
# Out:
# ['<div>\n        <p><span>Diese Hackathon Seite richtet sich an die Teilnehmer des #WirVsVirus Hackathons, die sich schon im #WirVsVirus Slack zu Herausforderungen ausgetauscht haben und nun ein Team starten oder einem Team beitreten wollen.\xa0</span></p>\n<p><span>Außerdem an die vielen Mentor:innen und Pat:innen.</span></p>\n      </div>', '<div>\n        <p><strong>Deadline</strong></p>\n<p><strong>Bis</strong> <strong>Sonntag, 18:00 Uhr</strong><span> (22.03.2020) solltet ihr auf DevPost ein Projekt angelegt und euer 2 Minuten Video hochgeladen und verlinkt haben.<br></span><strong>Sonntag 23:55 Uhr</strong><span> (22.03.2020) solltet ihr euer Projekt auf DevPost einreichen.\xa0</span></p>\n<p><span><span>\xa0</span></span></p>\n<p><strong>Video Veröffentlichung</strong></p>\n<ul>\n<li><span>Lade dein Pitch Video* auf YouTube oder einer alternativen Videoplattform hoch und verlinke es auf eurer DevPost Seite.</span></li>\n<li><span>Achte darauf, dass das Video nicht als privat markiert ist und jeder Zugriff auf den Link hat.\xa0</span></li>\n<li><span>Videos sollten </span><strong>maximal 2 Minuten </strong><span>lang sein. Nur die ersten zwei Minuten jedes Videos werden von uns und der Jury bewertet.\xa0</span></li>\n</ul>\n<p><span><strong><br>Code Veröffentlichung</strong></span></p>\n<ul>\n<li><span>Wenn ihr zur Lösung eurer Herausforderung etwas programmiert habt veröffentlicht den Code bitte auf </span><a href="https://github.com/WirVsVirus"><span>GitHub</span></a><span> und verlinkt euren Code auf eurer DevPost Seite.</span></li>\n</ul>\n<p><span><strong><br>Bewertung</strong></span></p>\n<p><span>All eure Projekte werden im Laufe der nächsten Woche von uns bewertet. Am Ende wählt eine Jury, die Projekte aus, die sie am vielversprechendsten finden. Damit es fair bleibt, werden die Projekte in drei Kategorien bewertet:</span></p>\n<ol>\n<li><span>Neuentwicklungen</span></li>\n<li><span>Weiterentwicklungen bestehender Lösungen</span></li>\n<li><span>Kommerzielle Lösungen</span></li>\n</ol>\n<p><span>Wir haben uns bewusst dagegen entschieden finanziellen Preise am Ende des Hackathons zu vergeben, aber wir werden so viele Projekte (besonders die von der Jury ausgewählten) wie möglich dabei unterstützen, weiter an der ihrer Lösungsidee zu arbeiten. Wir bewerten alle Einreichungen nach den folgenden Kriterien.</span></p>\n<p>\xa0</p>\n<p><strong>Fragen &amp; Antworten / FAQs zur DevPost Einreichung<br></strong><span><a href="https://docs.google.com/document/d/1tHsAZ6pofevpRnOsFl_r2wYTSdt615HemavuiyFyf9E/edit?usp=sharing">FAQs zu DevPost<br></a><a href="https://docs.google.com/document/d/1O1ewO6vhR-CDLPSm7kScPt8-xjsb-hKI2rXISRN8LI4/edit?usp=sharing">Anleitung zum Anlegen eines Projekts auf DevPost</a></span></p>\n<p>\xa0</p>\n<p><strong>*Guides für ein gutes Video</strong></p>\n<ul>\n<li><span>Stellt euch kurz vor (Namen des Projekts und des Teams)</span></li>\n</ul>\n<ul>\n<li><span>Beschreibe dein Projekt in einem Satz</span></li>\n<li><span>Sage ein paar Sätze zu: warum ist dein Projekt wichtig? welche Herausforderung willst du damit meistern? Wem kommt dein Projekt zugute?</span></li>\n</ul>\n      </div>']
